# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# 🟢 BASIC LEVEL (1–10)
#
# Read the CSV file into a Pandas DataFrame.
#
# Display the first 10 rows of the dataset.
#
# Display the last 5 rows of the dataset.
#
# Print the total number of rows and columns.
#
# Print all column names.
#
# Check the data types of each column.
#
# Show basic statistical summary of numerical columns.
#
# Select only the columns name, room_type, and price.
#
# Count how many listings are there in total.
#
# Find how many unique neighbourhood_group values exist.
#
# 🟡 MEDIUM LEVEL (11–20)
#
# Check how many missing values exist in each column.
#
# Drop all rows where price is missing.
#
# Fill missing values in reviews_per_month with 0.
#
# Convert the last_review column into datetime format.
#
# Find the average price of all listings.
#
# Find the minimum and maximum price.
#
# Count how many listings are there for each room_type.
#
# Find the average price for each neighbourhood_group.
#
# Filter listings where price is greater than 300.
#
# Sort the dataset by number_of_reviews in descending order.
#
# 🔵 HARD LEVEL (21–30)
#
# Find the neighbourhood group with the highest average price.
#
# Find the top 10 most reviewed listings.
#
# Find listings where minimum_nights is greater than 30.
#
# Find hosts who own more than 5 listings.
#
# Create a new column price_per_night_category:
#
# Low if price < 100
#
# Medium if price between 100–300
#
# High if price > 300
#
# Find the average availability (availability_365) for each room type.
#
# Find listings that have never been reviewed.
#
# Find the most common neighbourhood.
#
# Calculate the percentage of missing values in each column.
#
# Prepare a cleaned dataset by:
#
# Removing rows with missing price
#
# Filling missing reviews_per_month with median
#
# Keeping only listings with availability_365 > 0
#
# 🧠 Bonus Challenge (Optional – ML Thinking)
#
# Encode room_type and neighbourhood_group using numerical values.
#
# Create a dataset suitable for predicting price.
#
# Select features and target column.

# %%
df=pd.read_csv("D:\ML\Math for ML\AB_NYC_2019.csv")
print(df.head().to_string())
# print(df.info)

# %%
print("Total number of unique id:",df["id"].nunique())
print("Total number of host id:",df["host_id"].nunique())
print("Total number of  neighbourhood_group:",df["neighbourhood_group"].nunique())
print("Total number of neighbourhood:",df["neighbourhood"].nunique())
print("Total number of room type is:",df["room_type"].nunique())

# %%
print("Is there any missing title name?\n",df["name"].isnull())
df["name"].fillna("No Name")
